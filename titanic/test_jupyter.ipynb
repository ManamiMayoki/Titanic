# %%
import pandas as pd
print("Ready for Kaggle!")
# Out:
# Ready for Kaggle!

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import LabelEncoder
cities=['Dhaka','Chittagong','Dhaka','Sylhet','Dhaka','Chittagong']
encoder=LabelEncoder()
encoded_cities=encoder.fit_transform(cities)
print(encoded_cities)
# Out:
# [1 0 1 2 1 0]

# %%
import pandas as pd
data=pd.DataFrame({
    'Color':['Red','Green','Blue','Red']
})
encoded_Color=pd.get_dummies(data)
print(encoded_Color)
# Out:
#    Color_Blue  Color_Green  Color_Red
# 0       False        False       True
# 1       False         True      False
# 2        True        False      False
# 3       False        False       True

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
age=[[10],[20],[30],[40]]

#StandardScaler
std=StandardScaler()
scaled_age=std.fit_transform(age)
print("Standard Scaler:\n",scaled_age)

#MinMaxScaler
mn=MinMaxScaler()
scaled_age_mn=mn.fit_transform(age)
print("MinMax Scaler:\n",scaled_age_mn)
# Out:
# Standard Scaler:
#  [[-1.34164079]
#  [-0.4472136 ]
#  [ 0.4472136 ]
#  [ 1.34164079]]
# MinMax Scaler:
#  [[0.        ]
#  [0.33333333]
#  [0.66666667]
#  [1.        ]]

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
import numpy as np
X=np.array([[1],[2],[3]])
Y=np.array([10000,20000,30000])
model=LinearRegression()
model.fit(X,Y)

predicted_salary=model.predict([[4]])
print(predicted_salary)
# Out:
# [40000.]

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
import numpy as np
X=np.array([[1],[2],[3],[4]])
Y=np.array([0,0,1,1])
model=LogisticRegression()
model.fit(X,Y)
print(model.predict([[2.5]]))
print(model.predict([[5]]))
print(model.predict([[0.5]]))
# Out:
# [1]
# [1]
# [0]

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
X=np.array([[1],[2],[3],[4]])
Y=np.array([0,0,1,1])
model=KNeighborsClassifier(n_neighbors=3)
model.fit(X,Y)
print(model.predict([[2.5]]))
print(model.predict([[5]]))
print(model.predict([[0.5]]))
# Out:
# [0]
# [1]
# [0]

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
import numpy as np
X=np.array([[1],[2],[3],[4]])
Y=np.array([0,0,1,1])
model=DecisionTreeClassifier()
model.fit(X,Y)
print(model.predict([[2.5]]))
print(model.predict([[5]]))
print(model.predict([[0.5]]))
# Out:
# [0]
# [1]
# [0]

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    mean_squared_error
)

# --- 1. CLASSIFICATION ---
X = np.array([[1], [2], [3], [4], [5], [6]])
y = np.array([0, 0, 0, 1, 1, 1])

# Use stratify to ensure both 0 and 1 are in the test set
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42, stratify=y
)

clf_model = LogisticRegression()
clf_model.fit(X_train, y_train)
y_pred = clf_model.predict(X_test)

print("=== CLASSIFICATION ===")
print(f"Actual:    {y_test}")
print(f"Predicted: {y_pred}")

# zero_division=0 prevents warnings if no positive samples are predicted
print(f"Accuracy:  {accuracy_score(y_test, y_pred):.2f}")
print(f"Precision: {precision_score(y_test, y_pred, zero_division=0):.2f}")
print(f"Recall:    {recall_score(y_test, y_pred, zero_division=0):.2f}")
print(f"F1-score:  {f1_score(y_test, y_pred, zero_division=0):.2f}")


# --- 2. REGRESSION ---
X_reg = np.array([[1], [2], [3], [4], [5]])
y_reg = np.array([10000, 20000, 30000, 40000, 50000])

X_train_r, X_test_r, y_train_r, y_test_r = train_test_split(
    X_reg, y_reg, test_size=0.2, random_state=42
)

reg_model = LinearRegression()
reg_model.fit(X_train_r, y_train_r)
y_pred_r = reg_model.predict(X_test_r)

print("\n=== REGRESSION ===")
print(f"Actual:    {y_test_r}")
print(f"Predicted: {y_pred_r}")
print(f"MSE:       {mean_squared_error(y_test_r, y_pred_r):.2f}")
# Out:
# === CLASSIFICATION ===
# Actual:    [1 0]
# Predicted: [1 0]
# Accuracy:  1.00
# Precision: 1.00
# Recall:    1.00
# F1-score:  1.00
#
# === REGRESSION ===
# Actual:    [20000]
# Predicted: [20000.]
# MSE:       0.00

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
import numpy as np
study_hours=np.array([[1],[2],[3],[4],[5]])
Result=np.array([0,0,0,1,1])
model=LogisticRegression()
model.fit(study_hours, Result)

print(model.predict([[6]]))
print(model.predict([[2.5]]))
print(model.predict([[3.5]]))
# Out:
# [1]
# [0]
# [0]
